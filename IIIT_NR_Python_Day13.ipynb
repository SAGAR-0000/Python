# %%
import pandas as pd
df=pd.read_csv(r"C:/Users/Asus/Desktop/iiitnr/synthetic_students_one_row.csv")
df
# Out:
# Empty DataFrame
# ...

# %%
new_df=df[["Name"],["Salary"],["Age"],["sex"],["Address"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['Name'], ['Salary'], ['Age'], ['sex'], ['Address'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 new_df=df[["Name"],["Salary"],["Age"],["sex"],["Address"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
# ...

# %%
new_df=pd.DataFrame()
a=1250
for i in df:
    while a>=1:
        new_df["Name"]=df[i]
        a-=1

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %%
raw = df[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 raw = df[0][0]
#
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:/Users/Asus/Desktop/iiitnr/synthetic_students_one_row.csv",header=None)

reshaped = df.values.reshape(-1, 5)

columns = ["Name", "ID", "Age", "Gender", "Address"]
newdf = pd.DataFrame(reshaped, columns=columns)

newdf.head()
# Out:
#               Name    ID Age  Gender                    Address
# 0    Liam Williams  2804  22  Female     996 Maple Ave, Chicago
# 1       John Smith  1992  24    Male       719 High St, Houston
# 2        Mia Davis  8474  18   Other       574 Main St, Houston
# 3  Elijah Williams  4035  23    Male  634 Pearl St, Los Angeles
# 4     Sophia Brown  2812  24  Female     242 Pearl St, New York

# %%
import pandas as pd
df=pd.read_csv(r"C:/Users/Asus/Desktop/iiitnr/synthetic_students_one_row.csv",header=None)
data=df.iloc[0].tolist()
persons=[data[i:i+5] for i in range(0,len(data),5)]
reshaped=pd.DataFrame(persons,columns=["Name","id","Age","Gender","Address"])
reshaped.head()
# Out:
#               Name    id  Age  Gender                    Address
# 0    Liam Williams  2804   22  Female     996 Maple Ave, Chicago
# 1       John Smith  1992   24    Male       719 High St, Houston
# 2        Mia Davis  8474   18   Other       574 Main St, Houston
# 3  Elijah Williams  4035   23    Male  634 Pearl St, Los Angeles
# 4     Sophia Brown  2812   24  Female     242 Pearl St, New York

# %%
# Extract kiye values ko row se
data = df.iloc[0].tolist()

# Split kiye 5-5 (1 person = 5 fields)
persons = [data[i:i+5] for i in range(0, len(data), 5)]

# phir convert to new DataFrame columns ke name ke sath
reshaped_df = pd.DataFrame(persons, columns=["Name", "ID", "Age", "Gender", "Address"])

# print kiye first 10 rows
reshaped_df.head(10)
# Out:
#                 Name    ID  Age  Gender                    Address
# 0      Liam Williams  2804   22  Female     996 Maple Ave, Chicago
# 1         John Smith  1992   24    Male       719 High St, Houston
# 2          Mia Davis  8474   18   Other       574 Main St, Houston
# 3    Elijah Williams  4035   23    Male  634 Pearl St, Los Angeles
# 4       Sophia Brown  2812   24  Female     242 Pearl St, New York
# 5  Isabella Williams  9557   18    Male   924 Main St, Los Angeles
# 6         Noah Davis  2155   21    Male     733 Maple Ave, Houston
# 7      Mia Rodriguez  4105   25   Other      378 Pearl St, Phoenix
# 8     Liam Rodriguez  2911   18  Female      502 Broadway, Phoenix
# 9        Liam Garcia  6011   22  Female     894 Broadway, New York

# %%
#data preprocessing ,visualisation ,split,models,classification regression

# %%
#classification: 0 or 1
#regression: represented as numeric data (prediction)
