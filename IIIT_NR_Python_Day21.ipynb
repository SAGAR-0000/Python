# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:/Users/Asus/Desktop/iiitnr/synthetic_ppg_hr_hrv.csv")

# %%
df.isnull().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 997    0
# 998    0
# 999    0
# HR     0
# HRV    0
# Length: 1002, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Columns: 1002 entries, 0 to HRV
# dtypes: float64(1002)
# memory usage: 1.5 MB

# %%
df.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    -0.000289    0.004262   -0.000772    0.002717   -0.004771    1.000285
# std      0.030565    0.027314    0.029666    0.030561    0.029784    0.031081
# min     -0.084517   -0.071322   -0.088374   -0.086531   -0.088678    0.914710
# 25%     -0.020335   -0.013573   -0.018472   -0.019496   -0.027873    0.981166
# 50%     -0.001914    0.005171    0.001498    0.001471   -0.002347    1.000856
# 75%      0.018644    0.022864    0.016550    0.024850    0.013474    1.019403
# max      0.075150    0.069494    0.093599    0.074293    0.075601    1.076005
#
#                 6           7           8           9  ...         992  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     0.900304    0.806710    0.729427    0.660375  ...   -0.000089
# ...

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.045539  0.040109 -0.005488  0.013948  0.041364  1.002595  0.913231
# 1  0.015386  0.036343 -0.015320 -0.010104  0.012693  0.962778  0.921986
# 2  0.006836  0.016363 -0.015034  0.014724 -0.024559  1.029745  0.871852
# 3 -0.014031  0.045874  0.043087 -0.011718 -0.018987  1.048041  0.847810
# 4  0.019718  0.057269  0.007446 -0.030470 -0.028092  0.981423  0.921978
#
#           7         8         9  ...       992       993       994       995  \
# 0  0.801378  0.734704  0.622268  ... -0.033492  0.046872  0.027272 -0.013206
# 1  0.819948  0.723547  0.671161  ... -0.014744 -0.001106  0.015958  0.012056
# 2  0.777967  0.771525  0.629667  ... -0.026308 -0.040046 -0.055315  0.023377
# 3  0.808489  0.703527  0.651654  ...  0.003176  0.027776  0.035006  0.003184
# 4  0.770633  0.729132  0.655903  ... -0.040280  0.032209 -0.024290 -0.015800
#
#         996       997       998       999        HR       HRV
# ...

# %%
x=df.drop(columns=['HR', 'HRV'])
y=df["HR"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['HR'], df['HRV'])
plt.xlabel('Heart Rate')
plt.ylabel('HRV')
plt.title('Heart Rate vs Heart Rate Variability')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for i in range(5):
    plt.plot(df.columns, df.iloc[i], label=f"Signal {i+1}")

plt.title("First 5 Row-wise Signals")
plt.xlabel("Time Step")
plt.ylabel("Signal Value")
plt.legend()
plt.grid(True)
plt.show()
